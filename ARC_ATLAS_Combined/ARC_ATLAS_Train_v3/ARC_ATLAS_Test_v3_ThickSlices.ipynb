# %%
# ===== Cell 1: imports & helpers =====
from pathlib import Path
import importlib.util, json, time, math, csv, re
from typing import Tuple, Dict, Any, List, Optional
import numpy as np
import nibabel as nib

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from scipy.ndimage import binary_erosion, distance_transform_edt

# ---------- Metrics ----------
def dice_soft(y: np.ndarray, p: np.ndarray) -> float:
    y = y.astype(np.float64); p = p.astype(np.float64)
    inter = (y * p).sum()
    return float((2.0 * inter) / (y.sum() + p.sum() + 1e-12))

def dice_hard(ybin: np.ndarray, pbin: np.ndarray) -> float:
    ybin = ybin.astype(np.float64); pbin = pbin.astype(np.float64)
    inter = (ybin * pbin).sum()
    return float((2.0 * inter) / (ybin.sum() + pbin.sum() + 1e-12))

def precision_recall(ybin: np.ndarray, pbin: np.ndarray):
    tp = float((ybin & pbin).sum())
    fp = float((~ybin & pbin).sum())
    fn = float((ybin & ~pbin).sum())
    prec = tp / (tp + fp + 1e-12)
    rec  = tp / (tp + fn + 1e-12)
    return float(prec), float(rec)

# ---------- Surface distances ----------
def _surface(mask: np.ndarray) -> np.ndarray:
    s = np.ones((3,3,3), dtype=bool)
    er = binary_erosion(mask.astype(bool), structure=s, border_value=0)
    return mask.astype(bool) & (~er)

def _directed_surface_distances(A_surf: np.ndarray, B_surf: np.ndarray, spacing):
    if not A_surf.any():
        return np.empty((0,), dtype=np.float64)
    edt = distance_transform_edt(~B_surf, sampling=spacing)
    return edt[A_surf]

def hd_assd(ybin: np.ndarray, pbin: np.ndarray, spacing=(1.0,1.0,1.0)) -> Dict[str, float]:
    ysurf = _surface(ybin); psurf = _surface(pbin)
    if (not ysurf.any()) or (not psurf.any()):
        return {"hd": float("nan"), "hd95": float("nan"), "assd": float("nan")}
    dY = _directed_surface_distances(ysurf, psurf, spacing)
    dP = _directed_surface_distances(psurf, ysurf, spacing)
    both = np.concatenate([dY, dP]) if (dY.size and dP.size) else np.array([], float)
    hd   = float(np.max(both)) if both.size else float("nan")
    hd95 = float(np.percentile(both, 95)) if both.size else float("nan")
    assd = float((dY.mean() + dP.mean()) / 2.0) if (dY.size and dP.size) else float("nan")
    return {"hd": hd, "hd95": hd95, "assd": assd}

# ---------- Key normalization ----------
def _norm_key(name: str) -> str:
    n = re.sub(r"\.nii(\.gz)?$", "", name or "")
    n = re.sub(r"_T1w", "", n)
    n = re.sub(r"_MNI_norm", "", n)
    n = re.sub(r"_lesion_mask(_MNI)?_clean", "", n)
    n = re.sub(r"_(soft|hard)$", "", n)
    return n

# ---------- Plotting utilities ----------
def _dropna(a):
    a = np.asarray(a, float)
    return a[~np.isnan(a)]

def _robust_limits_log(arr):
    arr = _dropna(arr)
    if arr.size == 0:
        return (1e-2, 1.0)
    lo = np.percentile(arr, 5)
    hi = np.percentile(arr, 95)
    lo = max(lo, 1e-2)
    hi = max(hi, lo * 1.5)
    return (lo, hi)

def violin(ax, data_seq, labels, y_label=None, ylim=None, log=False, title=None):
    # Always use numeric x positions to avoid categorical converter issues.
    clean = [_dropna(x) for x in data_seq]
    nonempty = [x if x.size else np.array([np.nan]) for x in clean]
    pos = np.arange(1, len(nonempty) + 1, dtype=float)
    parts = ax.violinplot(nonempty, positions=pos, showmeans=True, showmedians=True, widths=0.8)
    for b in parts.get('bodies', []):
        b.set_alpha(0.6)
    if parts.get('cmeans') is not None: parts['cmeans'].set_linewidth(1.5)
    if parts.get('cmedians') is not None: parts['cmedians'].set_linewidth(1.5)
    ax.set_xticks(pos)
    ax.set_xticklabels(labels, rotation=0)
    if y_label: ax.set_ylabel(y_label)
    if log: ax.set_yscale("log")
    if ylim: ax.set_ylim(*ylim)
    elif not log: ax.set_ylim(0, 1.0)
    if title: ax.set_title(title)
    ax.grid(True, axis='y', alpha=0.2)

def composite_figure(per_case_rows: List[Dict[str, Any]], summary: Dict[str, Any], title="Held-out evaluation"):
    # pull arrays
    soft = np.array([r["soft_dice"] for r in per_case_rows], float)
    hard_key = next((k for k in per_case_rows[0].keys() if k.startswith("hard_dice_at_")), "hard_dice_at_0.50")
    hard = np.array([r[hard_key] for r in per_case_rows], float)
    prec = np.array([r["precision"] for r in per_case_rows], float)
    rec  = np.array([r["recall"] for r in per_case_rows], float)
    hd   = np.array([r["hd"] for r in per_case_rows], float)
    hd95 = np.array([r["hd95"] for r in per_case_rows], float)
    assd = np.array([r["assd"] for r in per_case_rows], float)

    fig = plt.figure(figsize=(10,8))
    gs = GridSpec(2, 1, height_ratios=[3,2], hspace=0.35)
    ax_top = fig.add_subplot(gs[0])
    ax_bot = fig.add_subplot(gs[1])

    # Top: Dice/PR violins
    violin(ax_top, [soft, hard, prec, rec],
           ["Soft Dice", "Hard Dice", "Precision", "Recall"],
           y_label="Value", title="Per-case distributions (Dice / Precision / Recall)")

    # Inset summary bars (numeric x positions)
    inset = ax_top.inset_axes([0.62, 0.55, 0.35, 0.38])
    bar_labels = ["Macro soft", "Macro hard", "Micro soft", "Micro hard"]
    bar_vals   = [summary["macro_soft"], summary["macro_hard"], summary["micro_soft"], summary["micro_hard"]]
    x = np.arange(len(bar_labels), dtype=float)
    inset.bar(x, bar_vals)
    inset.set_ylim(0, 1.0)
    inset.set_xticks(x)
    inset.set_xticklabels(bar_labels, rotation=20, ha='right', fontsize=8)
    inset.set_title("Summary Dice", fontsize=9)
    inset.grid(True, axis='y', alpha=0.2)

    # Bottom: distance violins (log scale, robust ylim)
    all_dist = np.concatenate([_dropna(hd), _dropna(hd95), _dropna(assd)]) if (
        np.isfinite(hd).any() or np.isfinite(hd95).any() or np.isfinite(assd).any()
    ) else np.array([1.0])
    ylim = _robust_limits_log(all_dist)
    violin(ax_bot, [hd, hd95, assd],
           ["HD", "HD95", "ASSD"],
           y_label="Distance (log scale; see units in summary)",
           ylim=ylim, log=True, title="Surface distance metrics (per-case)")

    fig.suptitle(title, y=0.99, fontsize=14)
    plt.tight_layout()
    return fig

# %%
# ===== Cell 2: end-to-end evaluation & save =====
def run_eval_and_viz(
    RUN_DIR: Path,
    TEST_DIR: Path,
    TRAIN_MOD_PATH: Path,
    T1_DIR: Optional[Path] = None,
    MSK_DIR: Optional[Path] = None,
    MANIFEST_CSV: Optional[Path] = None,
    TH: float = 0.50,
    save_prefix: str = "test",
    dataset_tag: str = "hires"
):
    # ---- import training module ----
    spec = importlib.util.spec_from_file_location("arc_seg_train", TRAIN_MOD_PATH)
    seg = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(seg)

    T1_DIR = T1_DIR or (TEST_DIR / "t1")
    MSK_DIR = MSK_DIR or (TEST_DIR / "masks")

    # ---- load model ----
    models_dir     = RUN_DIR / "models"
    callbacks_dir  = RUN_DIR / "callbacks"
    full_models    = sorted(models_dir.glob("*.keras"))
    best_weights   = callbacks_dir / "best_model_dynamic.weights.h5"
    cfg_json_path  = models_dir / "config.json"
    custom_objects = {
        "ResidualConvBlock": seg.ResidualConvBlock,
        "VisionMambaBlock": seg.VisionMambaBlock,
        "SAM2Attention": seg.SAM2Attention,
        "CombinedLoss": seg.CombinedLoss,
        "dice_coefficient": seg.dice_coefficient,
        "dice_loss": seg.dice_loss,
        "boundary_loss": seg.boundary_loss,
    }
    try:
        from keras.saving import load_model as keras_load_model
    except Exception:
        from tensorflow.keras.models import load_model as keras_load_model

    if full_models:
        model_path = full_models[-1]
        print(f"Loading FULL model: {model_path}")
        model = keras_load_model(model_path, compile=False, custom_objects=custom_objects)
        INPUT_SHAPE = tuple(model.input_shape[1:])
    else:
        assert cfg_json_path.exists(), f"Missing {cfg_json_path}"
        with open(cfg_json_path) as f:
            saved_cfg = json.load(f)
        cfg = seg.DynamicTrainingConfig(
            DATA_DIR=TEST_DIR, MODEL_DIR=models_dir, CALLBACKS_DIR=callbacks_dir,
            INPUT_SHAPE=tuple(saved_cfg["INPUT_SHAPE"]) if saved_cfg.get("INPUT_SHAPE") else None,
            BASE_FILTERS=int(saved_cfg.get("BASE_FILTERS", 8)),
            SAM_HEADS=int(saved_cfg.get("SAM_HEADS", 2)),
        )
        if not cfg.INPUT_SHAPE:
            raise RuntimeError("INPUT_SHAPE missing in saved config; cannot rebuild model.")
        INPUT_SHAPE = cfg.INPUT_SHAPE
        print("Rebuilding model from config.json and loading best weights…")
        model = seg.build_dynamic_model(cfg)
        model.load_weights(str(best_weights))

    print("INPUT_SHAPE:", INPUT_SHAPE)

    # ---- dataset ----
    if T1_DIR.exists() and MSK_DIR.exists():
        cfg_eval = seg.DynamicTrainingConfig(DATA_DIR=TEST_DIR, IMAGES_DIR=T1_DIR, MASKS_DIR=MSK_DIR,
                                             MODEL_DIR=RUN_DIR/"_tmp_models", CALLBACKS_DIR=RUN_DIR/"_tmp_callbacks")
    else:
        cfg_eval = seg.DynamicTrainingConfig(DATA_DIR=TEST_DIR,
                                             MODEL_DIR=RUN_DIR/"_tmp_models", CALLBACKS_DIR=RUN_DIR/"_tmp_callbacks")
    cfg_eval.INPUT_SHAPE = INPUT_SHAPE
    pairs, lesion_presence = seg.load_generic_dataset(cfg_eval)
    print(f"Pairs: {len(pairs)} | % non-empty masks: {lesion_presence.mean()*100:.1f}%")

    # ---- spacing inference (best-effort) ----
    use_mm = True
    spacing = (1.0, 1.0, 1.0)
    try:
        z = nib.load(str(pairs[0][0])).header.get_zooms()[:3]
        if any(abs(zi - 1.0) > 0.05 for zi in z):
            use_mm = False
    except Exception:
        use_mm = False

    # ---- quality metrics computed on each degraded image (not borrowed from base manifest) ----
    from scipy.ndimage import laplace

    def _q_zscore_in_brain(vol: np.ndarray):
        m = vol != 0
        out = np.zeros_like(vol, dtype=np.float32)
        if m.any():
            vv = vol[m].astype(np.float32)
            sd = float(vv.std())
            sd = sd if sd > 0 else 1.0
            out[m] = (vv - float(vv.mean())) / sd
        return out, m

    def _q_fwhm_gaussian_acf(img: np.ndarray, mask: np.ndarray, shifts=(1, 2, 3), max_fwhm_mm=50.0, min_pairs=1000):
        cors = []
        for sh in shifts:
            for axis in (0, 1, 2):
                sf = [slice(None)] * 3
                sg = [slice(None)] * 3
                sf[axis] = slice(0, -sh)
                sg[axis] = slice(sh, None)
                f = img[tuple(sf)]
                g = img[tuple(sg)]
                m = mask[tuple(sf)] & mask[tuple(sg)]
                if int(m.sum()) < min_pairs:
                    continue
                fv = f[m] - float(f[m].mean())
                gv = g[m] - float(g[m].mean())
                sd = float(fv.std()) * float(gv.std())
                if sd <= 1e-8:
                    continue
                r = float((fv * gv).mean() / sd)
                r = max(min(r, 0.999), 1e-6)
                cors.append((sh, r))
        if not cors:
            return float("nan")

        by_shift = {}
        for sh, rr in cors:
            by_shift.setdefault(sh, []).append(rr)
        s2 = np.array(sorted(by_shift), dtype=float) ** 2
        R = np.array([np.mean(by_shift[sh]) for sh in sorted(by_shift)], dtype=float)
        lnR = np.log(R)
        if not np.all(np.isfinite(lnR)):
            return float("nan")

        A = np.vstack([np.ones_like(s2), s2]).T
        _, b = np.linalg.lstsq(A, lnR, rcond=None)[0]
        if (not np.isfinite(b)) or b >= -1e-6:
            return float("nan")

        sigma = np.sqrt(-1.0 / (2.0 * b))
        fwhm = 2.355 * sigma
        if (not np.isfinite(fwhm)) or fwhm <= 0 or fwhm > max_fwhm_mm:
            return float("nan")
        return float(fwhm)

    def _q_high_freq_energy_ratio(img: np.ndarray, mask: np.ndarray, cutoff=0.25):
        from numpy.fft import fftn, fftshift

        vol = np.zeros_like(img, dtype=np.float32)
        vol[mask] = img[mask]
        F = fftshift(fftn(vol))
        P = (np.abs(F) ** 2).astype(np.float64)
        tot = float(P.sum())
        if (not np.isfinite(tot)) or tot <= 1e-12:
            return float("nan")

        nx, ny, nz = img.shape
        cx, cy, cz = (np.array(img.shape) - 1) / 2.0
        x = np.arange(nx) - cx
        y = np.arange(ny) - cy
        z = np.arange(nz) - cz
        X, Y, Z = np.meshgrid(x, y, z, indexing="ij")
        rx = np.abs(X) / (nx / 2.0)
        ry = np.abs(Y) / (ny / 2.0)
        rz = np.abs(Z) / (nz / 2.0)
        r = np.sqrt((rx ** 2 + ry ** 2 + rz ** 2) / 3.0)

        hf = float(P[r >= cutoff].sum())
        return float(hf / (tot + 1e-12))

    def _q_laplacian_variance(img: np.ndarray, mask: np.ndarray):
        L = laplace(img)
        vals = L[mask]
        return float(vals.var()) if vals.size else float("nan")

    quality_by_key: Dict[str, Dict[str, float]] = {}

    # ---- eval loop ----
    macro_softs, macro_hards = [], []
    precisions, recalls = [], []
    hds, hd95s, assds = [], [], []   # <-- fixed tuple init
    s_inter_soft = np.float64(0.0); s_sumy_soft = np.float64(0.0); s_sump_soft = np.float64(0.0)

    per_case_rows = []
    for i, (img_p, msk_p) in enumerate(pairs, 1):
        img = seg._load_and_preprocess_image(str(img_p), INPUT_SHAPE[:-1]).astype(np.float32)
        y   = seg._load_and_preprocess_mask(str(msk_p),  INPUT_SHAPE[:-1]).astype(np.float32)
        x = np.zeros((1,*INPUT_SHAPE), np.float32); x[0,...,0] = img
        p  = model.predict(x, verbose=0)[0,...,0].astype(np.float32)
        pb = (p >= TH)

        ds = dice_soft(y, p)
        dh = dice_hard(y > 0.5, pb)
        yy = (y > 0.5)
        prec, rec = precision_recall(yy, pb)
        dists = hd_assd(yy, pb, spacing=spacing)

        macro_softs.append(ds); macro_hards.append(dh)
        precisions.append(prec); recalls.append(rec)
        hds.append(dists["hd"]); hd95s.append(dists["hd95"]); assds.append(dists["assd"])

        s_inter_soft += (y.astype(np.float64) * p.astype(np.float64)).sum()
        s_sumy_soft  += y.sum(dtype=np.float64)
        s_sump_soft  += p.sum(dtype=np.float64)

        # quality metrics on the current degraded image
        q_key = _norm_key(Path(img_p).stem)
        try:
            raw = nib.load(str(img_p)).get_fdata().astype(np.float32)
            zimg, qmask = _q_zscore_in_brain(raw)
            if int(qmask.sum()) >= 5000:
                q_fwhm = _q_fwhm_gaussian_acf(zimg, qmask)
                q_hfe = _q_high_freq_energy_ratio(zimg, qmask, cutoff=0.25)
                q_lvar = _q_laplacian_variance(zimg, qmask)
            else:
                q_fwhm = q_hfe = q_lvar = float("nan")
        except Exception:
            q_fwhm = q_hfe = q_lvar = float("nan")

        quality_by_key[q_key] = {
            "fwhm_mm": float(q_fwhm),
            "hi_freq_energy": float(q_hfe),
            "lap_var": float(q_lvar),
        }

        if i % 10 == 0 or i == len(pairs):
            print(f"[{i}/{len(pairs)}] soft={ds:.4f} hard@{TH:.2f}={dh:.4f} | P={prec:.3f} R={rec:.3f} | "
                  f"HD={dists['hd']:.2f} HD95={dists['hd95']:.2f} ASSD={dists['assd']:.2f}")

        per_case_rows.append({
            "dataset_tag": dataset_tag,
            "key": _norm_key(Path(img_p).stem),
            "soft_dice": float(ds),
            f"hard_dice_at_{TH:.2f}": float(dh),
            "precision": float(prec),
            "recall": float(rec),
            "hd": float(dists["hd"]),
            "hd95": float(dists["hd95"]),
            "assd": float(dists["assd"]),
            "img_path": str(img_p),
            "mask_path": str(msk_p),
        })

    # micro hard (exact)
    s_inter_hard = np.float64(0.0); s_sumy_hard  = np.float64(0.0); s_sump_hard  = np.float64(0.0)
    for img_p, msk_p in pairs:
        y = seg._load_and_preprocess_mask(str(msk_p), INPUT_SHAPE[:-1]).astype(np.float32)
        x = np.zeros((1,*INPUT_SHAPE), np.float32)
        x[0,...,0] = seg._load_and_preprocess_image(str(img_p), INPUT_SHAPE[:-1]).astype(np.float32)
        p = model.predict(x, verbose=0)[0,...,0]
        pb = (p >= TH).astype(np.float64)
        s_inter_hard += (y.astype(np.float64) * pb).sum()
        s_sumy_hard  += y.sum(dtype=np.float64)
        s_sump_hard  += pb.sum(dtype=np.float64)

    macro_soft = float(np.mean(macro_softs))
    macro_hard = float(np.mean(macro_hards))
    micro_soft = float((2.0*s_inter_soft) / (s_sumy_soft + s_sump_soft + 1e-12))
    micro_hard = float((2.0*s_inter_hard) / (s_sumy_hard + s_sump_hard + 1e-12))

    out_dir = RUN_DIR / "test_eval"; out_dir.mkdir(parents=True, exist_ok=True)
    ts = time.strftime("%Y%m%d_%H%M%S")
    csv_path  = out_dir / f"{save_prefix}_metrics_{ts}.csv"
    json_path = out_dir / f"{save_prefix}_metrics_summary_{ts}.json"
    png_path  = out_dir / f"{save_prefix}_composite_{ts}.png"

    # write CSV
    with open(csv_path, "w", newline="") as f:
        cols = list(per_case_rows[0].keys()) if per_case_rows else []
        wr = csv.DictWriter(f, fieldnames=cols)
        wr.writeheader(); wr.writerows(per_case_rows)

    summary = {
        "threshold": TH,
        "macro_soft": macro_soft, "macro_hard": macro_hard,
        "micro_soft": micro_soft, "micro_hard": micro_hard,
        "n_cases": len(pairs),
        "distance_units": "mm (assumed 1mm isotropic MNI)" if use_mm else "voxel units (spacing unknown on model grid)",
        "run_dir": str(RUN_DIR), "test_dir": str(TEST_DIR),
        "csv_path": str(csv_path)
    }
    with open(json_path, "w") as f:
        json.dump(summary, f, indent=2)

    print("\n=== SUMMARY ===")
    print(f"Macro soft Dice : {macro_soft:.4f}")
    print(f"Macro hard Dice : {macro_hard:.4f}")
    print(f"Micro soft Dice : {micro_soft:.4f}")
    print(f"Micro hard Dice : {micro_hard:.4f}")
    print(f"Per-case CSV    : {csv_path}")
    print(f"Summary  JSON   : {json_path}")

    # figure
    fig = composite_figure(per_case_rows, summary,
                           title=f"{dataset_tag}: held-out evaluation")
    fig.savefig(png_path, dpi=150, bbox_inches="tight")
    plt.show()
    print("Composite figure:", png_path)

    # Merge with manifest metadata, but ALWAYS use per-image computed quality metrics.
    merged_csv_path = None
    manifest = {}
    if MANIFEST_CSV and Path(MANIFEST_CSV).exists():
        with open(MANIFEST_CSV, newline="") as f:
            for row in csv.DictReader(f):
                k = (row.get("key") or "").strip()
                if not k:
                    for src in (row.get("t1_path"), row.get("mask_path")):
                        if src:
                            k = _norm_key(Path(src).name)
                            break
                if not k:
                    continue
                manifest[k] = row

    merged = []
    for r in per_case_rows:
        m = manifest.get(r["key"], {})
        q = quality_by_key.get(r["key"], {})
        row = {**r, **{f"mf_{kk}": vv for kk, vv in m.items()}}

        # Backfill baseline metadata if no manifest row is found.
        row.setdefault("mf_dataset", dataset_tag)
        row.setdefault("mf_key", r["key"])
        row.setdefault("mf_t1_path", r.get("img_path", ""))
        row.setdefault("mf_mask_path", r.get("mask_path", ""))
        row.setdefault("mf_bin", dataset_tag)

        # Critical fix: quality comes from degraded image, not source manifest.
        row["mf_fwhm_mm"] = float(q.get("fwhm_mm", np.nan))
        row["mf_hi_freq_energy"] = float(q.get("hi_freq_energy", np.nan))
        row["mf_lap_var"] = float(q.get("lap_var", np.nan))
        merged.append(row)

    # Recompute mf_score from the per-image quality values (dataset-level z-score sum).
    fwhm_arr = np.array([float(r.get("mf_fwhm_mm", np.nan)) for r in merged], dtype=float)
    hfe_arr  = np.array([float(r.get("mf_hi_freq_energy", np.nan)) for r in merged], dtype=float)
    lap_arr  = np.array([float(r.get("mf_lap_var", np.nan)) for r in merged], dtype=float)

    def _z(v: np.ndarray) -> np.ndarray:
        out = np.full(v.shape, np.nan, dtype=float)
        m = np.isfinite(v)
        if m.sum() == 0:
            return out
        mu = float(np.mean(v[m]))
        sd = float(np.std(v[m]))
        if sd < 1e-12:
            out[m] = 0.0
        else:
            out[m] = (v[m] - mu) / sd
        return out

    score = _z(hfe_arr) + _z(lap_arr) + _z(-fwhm_arr)
    for rr, sc in zip(merged, score):
        rr["mf_score"] = float(sc) if np.isfinite(sc) else np.nan

    if merged:
        merged_csv_path = out_dir / f"{save_prefix}_metrics_with_manifest_{ts}.csv"
        with open(merged_csv_path, "w", newline="") as f:
            wr = csv.DictWriter(f, fieldnames=list(merged[0].keys()))
            wr.writeheader()
            wr.writerows(merged)
        print("Merged CSV with manifest ->", merged_csv_path)

    return per_case_rows, summary, {"per_case_csv": csv_path, "summary_json": json_path,
                                    "figure_png": png_path, "merged_csv": merged_csv_path}

# %%
# ===== Cell 3 (FINAL): RUN full evaluation on one dataset, compute summaries (no plots) =====
from pathlib import Path
import csv, json
import numpy as np
from typing import Dict, List, Any

# ---- small helpers (NaN-safe summaries) ----
def _dropna(a):
    a = np.asarray(a, float)
    return a[~np.isnan(a)]

def summarize_vector(x) -> Dict[str, float]:
    v = _dropna(np.array(x, float))
    if v.size == 0:
        return dict(n=0, mean=np.nan, median=np.nan, std=np.nan,
                    p25=np.nan, p75=np.nan, min=np.nan, max=np.nan, nan_count=len(x))
    return dict(
        n=int(v.size),
        mean=float(np.mean(v)),
        median=float(np.median(v)),
        std=float(np.std(v, ddof=1)) if v.size > 1 else 0.0,
        p25=float(np.percentile(v,25)),
        p75=float(np.percentile(v,75)),
        min=float(np.min(v)),
        max=float(np.max(v)),
        nan_count=int(len(x) - v.size),
    )

def summarize_dataset(rows: List[Dict[str, Any]]) -> Dict[str, Any]:
    soft = [r["soft_dice"] for r in rows]
    # detect the hard-dice column name we wrote in Cell 2
    hard_key = next((k for k in rows[0].keys() if k.startswith("hard_dice_at_")), "hard_dice_at_0.50")
    hard = [r[hard_key] for r in rows]
    prec = [r["precision"] for r in rows]
    rec  = [r["recall"]   for r in rows]
    hd   = [r["hd"]       for r in rows]
    hd95 = [r["hd95"]     for r in rows]
    assd = [r["assd"]     for r in rows]
    return {
        "soft": summarize_vector(soft),
        "hard": summarize_vector(hard),
        "prec": summarize_vector(prec),
        "rec":  summarize_vector(rec),
        "hd":   summarize_vector(hd),
        "hd95": summarize_vector(hd95),
        "assd": summarize_vector(assd),
    
    }

def write_summary_csv(summary_table: List[Dict[str, Any]], out_path: Path):
    if not summary_table:
        print("No summary to write."); return
    keys = sorted({k for row in summary_table for k in row.keys()})
    with open(out_path, "w", newline="") as f:
        wr = csv.DictWriter(f, fieldnames=keys)
        wr.writeheader(); wr.writerows(summary_table)
    print("Wrote summary CSV ->", out_path)

# -------- RUN THIS BLOCK (edit paths/tag/prefix only) --------
RUN_DIR   = Path("/home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813")
TEST_DIR  = Path("/home/rbielski/ARC/ds004884/derivatives/aggregates/t1w_with_masks/mni_1mm_ants_fixed/_standardized/_combined_manifests_2bins_normal/_combined_splits_70_30_global/test_hires_thickslice_1x1x5mm_backTo1mm")
TRAIN_MOD = Path("/home/rbielski/stroke_cleaned/stroke_segmentation_v1.2/stroke_seg_v1.2_train.py")
T1_DIR    = TEST_DIR / "t1"
MSK_DIR   = TEST_DIR / "masks"
MANIFEST  = Path("/home/rbielski/ARC/ds004884/derivatives/aggregates/t1w_with_masks/mni_1mm_ants_fixed/_standardized/_combined_manifests_2bins_normal/combined_hires_lores_manifest.csv")

DATASET_TAG = "lores"         # <<< change per dataset (e.g., "lores", "thickslice")
SAVE_PREFIX = "test_lores"     # <<< change per dataset

# 1) Run the full evaluation over ALL images (model inference + metrics + CSV/JSON/PNG)
rows, summary, paths = run_eval_and_viz(
    RUN_DIR=RUN_DIR, TEST_DIR=TEST_DIR, TRAIN_MOD_PATH=TRAIN_MOD,
    T1_DIR=T1_DIR, MSK_DIR=MSK_DIR, MANIFEST_CSV=MANIFEST,
    TH=0.50, save_prefix=SAVE_PREFIX, dataset_tag=DATASET_TAG
)

# 2) Build the 'datasets' dict Cell 4 expects (from in-memory rows)
datasets: Dict[str, Dict[str, Any]] = {
    DATASET_TAG: {
        "rows": rows,                         # per-case metrics (list of dicts)
        "summary": summarize_dataset(rows),   # mean/median/std/etc per metric
        "source_paths": [paths["per_case_csv"]]
    }
}

# 3) Also write a tiny one-row summary CSV for this dataset (next to the per-case CSV)
summary_table = []
flat = {"dataset_tag": DATASET_TAG}
for metric, stats in datasets[DATASET_TAG]["summary"].items():
    for k, v in stats.items():
        flat[f"{metric}_{k}"] = v
summary_table.append(flat)
out_summary = Path(paths["per_case_csv"]).with_name(f"{SAVE_PREFIX}_summary_stats.csv")
write_summary_csv(summary_table, out_summary)

print("Datasets ready for plotting:", list(datasets.keys()))
print(f"Rows: {len(datasets[DATASET_TAG]['rows'])} | Saved per-case CSV: {paths['per_case_csv']}")
print(f"Saved one-row summary CSV: {out_summary}")
# Out:
# 2025-11-11 16:05:14.754549: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762902316.274958 1880174 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1762902316.276091 1880174 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 901 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# I0000 00:00:1762902316.276379 1880174 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 1
# I0000 00:00:1762902316.277434 1880174 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 12507 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# 2025-11-11 16:05:16,323 - SmartSOTA_Dynamic - INFO - ✅ All imports successful
# 2025-11-11 16:05:16,323 - SmartSOTA_Dynamic - INFO - TensorFlow eager execution: True
# 2025-11-11 16:05:16,323 - SmartSOTA_Dynamic - INFO - Environment verified:
# - Python 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]
# - TensorFlow 2.20.0
# - NumPy 2.2.1
# - GPU devices: 2
# Strategy: MirroredStrategy
# Loading FULL model: /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/models/smart_sota_dynamic_20251110_101813.keras
# 2025-11-11 16:05:17,670 - SmartSOTA_Dynamic - INFO - 📚 Loading dataset (flex loader for T1w volumes)…
# 2025-11-11 16:05:17,671 - SmartSOTA_Dynamic - INFO - Memory at dataset_load_start: CPU=0.99GB | GPU mem tracking failed | Disk: 1240.6GB free
# 2025-11-11 16:05:17,674 - SmartSOTA_Dynamic - INFO - 📁 Single-folder mode: 138 images, 138 masks in /home/rbielski/ARC/ds004884/derivatives/aggregates/t1w_with_masks/mni_1mm_ants_fixed/_standardized/_combined_manifests_2bins_normal/_combined_splits_70_30_global/test_hires_thickslice_1x1x5mm_backTo1mm
# 2025-11-11 16:05:17,674 - SmartSOTA_Dynamic - INFO - Found 138 image files and 138 mask files
# INPUT_SHAPE: (192, 224, 192, 1)
# 2025-11-11 16:05:36,051 - SmartSOTA_Dynamic - INFO - 📊 Created 138 image–mask pairs
# 2025-11-11 16:05:36,052 - SmartSOTA_Dynamic - INFO - 🧠 Lesion presence: 100.00%
# 2025-11-11 16:05:36,053 - SmartSOTA_Dynamic - INFO - Memory at dataset_load_end: CPU=1.00GB | GPU mem tracking failed | Disk: 1240.6GB free
# Pairs: 138 | % non-empty masks: 100.0%
# 2025-11-11 16:05:37.081164: I external/local_xla/xla/service/service.cc:163] XLA service 0x7aa8440086d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-11 16:05:37.081193: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-11-11 16:05:37.081200: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-11-11 16:05:37.181368: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-11 16:05:37.455185: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91001
# 2025-11-11 16:05:38.448093: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 2395983408 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.448122: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       557459996
# MaxInUse:                    838481836
# NumAllocs:                         990
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.448146: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.448151: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.448155: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.448159: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.448162: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.448166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.448169: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.448173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.448176: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.448179: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.448183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.448186: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.448190: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.448193: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.448196: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.448200: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.448203: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.448207: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.448210: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.448214: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.448217: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.448220: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.448224: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.448227: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.448231: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.448234: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.448237: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.448241: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.448244: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.448248: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.448251: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.448254: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.448258: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777232, 1
# 2025-11-11 16:05:38.448261: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16780672, 1
# 2025-11-11 16:05:38.448267: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.448271: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 3
# 2025-11-11 16:05:38.448277: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.448281: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 557459996
# 2025-11-11 16:05:38.448285: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.448288: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.564026: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.564049: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.564072: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.564077: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.564081: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.564085: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.564088: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.564091: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.564095: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.564098: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.564102: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.564105: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.564108: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.564112: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.564115: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.564119: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.564122: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.564125: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.564129: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.564133: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.564136: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.564139: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.564143: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.564147: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.564150: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.564154: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.564156: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.564159: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.564162: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.564163: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.564165: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.564166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.564168: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.564169: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.564170: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.564172: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.564173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.564175: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.564176: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.564178: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.564180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.564182: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.564183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.572066: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.572084: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.572101: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.572105: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.572109: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.572113: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.572116: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.572119: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.572123: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.572126: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.572130: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.572133: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.572136: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.572140: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.572143: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.572146: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.572150: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.572153: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.572157: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.572160: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.572164: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.572168: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.572171: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.572174: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.572177: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.572180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.572183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.572185: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.572186: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.572187: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.572190: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.572192: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.572193: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.572194: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.572196: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.572197: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.572198: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.572200: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.572202: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.572204: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.572205: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.572207: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.572209: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.580065: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.580078: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.580086: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.580088: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.580091: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.580093: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.580095: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.580097: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.580100: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.580102: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.580104: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.580106: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.580108: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.580110: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.580112: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.580114: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.580116: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.580119: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.580121: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.580123: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.580125: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.580127: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.580129: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.580131: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.580133: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.580136: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.580138: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.580140: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.580142: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.580144: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.580148: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.580150: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.580152: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.580155: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.580157: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.580159: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.580161: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.580163: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.580165: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.580168: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.580171: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.580173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.580175: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.588072: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.588086: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.588093: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.588096: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.588099: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.588101: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.588103: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.588105: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.588108: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.588110: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.588112: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.588114: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.588116: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.588118: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.588120: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.588122: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.588124: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.588126: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.588129: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.588131: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.588133: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.588135: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.588137: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.588139: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.588141: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.588143: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.588145: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.588147: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.588150: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.588152: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.588155: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.588157: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.588160: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.588162: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.588164: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.588166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.588168: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.588170: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.588172: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.588175: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.588177: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.588180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.588182: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.596061: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.596079: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.596091: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.596094: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.596097: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.596100: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.596102: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.596104: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.596106: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.596108: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.596110: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.596112: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.596114: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.596116: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.596118: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.596121: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.596123: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.596125: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.596127: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.596129: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.596131: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.596133: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.596135: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.596137: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.596139: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.596141: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.596143: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.596146: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.596148: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.596150: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.596153: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.596156: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.596158: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.596160: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.596162: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.596164: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.596166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.596168: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.596170: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.596173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.596176: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.596178: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.596180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.604065: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.604082: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.604095: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.604100: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.604103: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.604106: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.604110: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.604113: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.604115: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.604117: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.604119: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.604121: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.604123: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.604125: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.604128: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.604130: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.604132: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.604134: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.604136: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.604138: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.604140: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.604142: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.604144: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.604147: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:38.604149: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:38.604151: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:38.604153: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:38.604155: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:38.604157: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:38.604159: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:38.604163: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:38.604165: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:38.604167: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:38.604169: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:38.604171: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777248, 1
# 2025-11-11 16:05:38.604173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777472, 1
# 2025-11-11 16:05:38.604175: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:38.604178: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:38.604180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 281018368, 2
# 2025-11-11 16:05:38.604183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:38.604186: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821697964
# 2025-11-11 16:05:38.604188: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:38.604190: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 838481836
# 2025-11-11 16:05:38.612062: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 413138960 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:38.612079: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821697964
# MaxInUse:                    838481836
# NumAllocs:                        1013
# MaxAllocSize:                281021840
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:38.612091: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:38.612096: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:38.612099: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:38.612103: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:38.612107: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:38.612110: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:38.612113: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:38.612117: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:38.612120: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:38.612123: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:38.612127: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:38.612130: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:38.612134: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:38.612137: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:38.612140: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:38.612144: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:38.612147: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:38.612151: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:38.612154: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:38.612158: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:38.612161: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:38.612164: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# ...
# 2025-11-11 16:05:40.856209: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:40.856212: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:40.856215: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:40.856219: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777232, 1
# 2025-11-11 16:05:40.856222: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777600, 1
# 2025-11-11 16:05:40.856226: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:40.856229: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 2
# 2025-11-11 16:05:40.856233: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 413138944, 1
# 2025-11-11 16:05:40.856238: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:40.856242: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821698076
# 2025-11-11 16:05:40.856246: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:40.856249: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 1102716332
# 2025-11-11 16:05:40.864067: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 4773634224 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:40.864085: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       821698076
# MaxInUse:                   1102716332
# NumAllocs:                        1798
# MaxAllocSize:                677500080
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:40.864100: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:40.864104: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:40.864108: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:40.864112: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:40.864115: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:40.864119: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:40.864122: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:40.864125: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:40.864129: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:40.864132: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:40.864135: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:40.864139: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:40.864142: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:40.864146: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:40.864149: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:40.864152: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:40.864156: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:40.864159: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:40.864163: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:40.864166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:40.864169: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:40.864173: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:40.864177: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:40.864180: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:40.864183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:40.864187: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:40.864190: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:40.864193: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:40.864200: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:40.864203: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:40.864207: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:40.864210: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:40.864213: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777232, 1
# 2025-11-11 16:05:40.864217: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777600, 1
# 2025-11-11 16:05:40.864222: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:40.864226: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 2
# 2025-11-11 16:05:40.864229: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 413138944, 1
# 2025-11-11 16:05:40.864234: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:40.864238: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 821698076
# 2025-11-11 16:05:40.864242: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:40.864245: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 1102716332
# 2025-11-11 16:05:41.000105: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:361] gpu_async_0 cuMemAllocAsync failed to allocate 2395980096 bytes: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
#  Reported by CUDA: Free memory/Total memory: 218234880/25261047808
# 2025-11-11 16:05:41.000137: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:366] Stats: Limit:                       944898048
# InUse:                       326245536
# MaxInUse:                   1102716332
# NumAllocs:                        1817
# MaxAllocSize:                677500080
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-11-11 16:05:41.000161: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:70] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-11-11 16:05:41.000166: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 4, 42
# 2025-11-11 16:05:41.000171: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8, 4
# 2025-11-11 16:05:41.000174: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16, 18
# 2025-11-11 16:05:41.000178: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32, 26
# 2025-11-11 16:05:41.000181: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 64, 24
# 2025-11-11 16:05:41.000184: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 128, 24
# 2025-11-11 16:05:41.000188: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 256, 24
# 2025-11-11 16:05:41.000191: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 512, 19
# 2025-11-11 16:05:41.000195: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 768, 1
# 2025-11-11 16:05:41.000198: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 864, 1
# 2025-11-11 16:05:41.000201: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1028, 1
# 2025-11-11 16:05:41.000205: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 2048, 5
# 2025-11-11 16:05:41.000208: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 3072, 1
# 2025-11-11 16:05:41.000212: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 6912, 2
# 2025-11-11 16:05:41.000215: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 8192, 5
# 2025-11-11 16:05:41.000218: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 12288, 1
# 2025-11-11 16:05:41.000222: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 13824, 1
# 2025-11-11 16:05:41.000225: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 20736, 1
# 2025-11-11 16:05:41.000229: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 27648, 4
# 2025-11-11 16:05:41.000232: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 32768, 5
# 2025-11-11 16:05:41.000235: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 49152, 1
# 2025-11-11 16:05:41.000239: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 55296, 1
# 2025-11-11 16:05:41.000242: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 65536, 4
# 2025-11-11 16:05:41.000246: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 82944, 1
# 2025-11-11 16:05:41.000249: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 110592, 4
# 2025-11-11 16:05:41.000253: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 221184, 1
# 2025-11-11 16:05:41.000256: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 331776, 1
# 2025-11-11 16:05:41.000259: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 442368, 4
# 2025-11-11 16:05:41.000263: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 884736, 1
# 2025-11-11 16:05:41.000266: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1327104, 1
# 2025-11-11 16:05:41.000269: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 1769472, 3
# 2025-11-11 16:05:41.000273: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777220, 1
# 2025-11-11 16:05:41.000276: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 16777232, 1
# 2025-11-11 16:05:41.000283: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33030144, 2
# 2025-11-11 16:05:41.000286: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 33292288, 2
# 2025-11-11 16:05:41.000289: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:73] 148897792, 1
# 2025-11-11 16:05:41.000295: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:106] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 939524096
# 2025-11-11 16:05:41.000299: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:108] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 326245536
# 2025-11-11 16:05:41.000303: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:109] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 1140850688
# 2025-11-11 16:05:41.000307: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:110] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 1102716332
# I0000 00:00:1762902342.807022 1880565 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# [10/138] soft=0.7861 hard@0.50=0.7868 | P=0.776 R=0.798 | HD=22.36 HD95=6.08 ASSD=1.98
# [20/138] soft=0.8171 hard@0.50=0.8171 | P=0.820 R=0.814 | HD=21.68 HD95=7.62 ASSD=2.53
# [30/138] soft=0.7867 hard@0.50=0.7871 | P=0.760 R=0.816 | HD=49.99 HD95=8.00 ASSD=2.38
# [40/138] soft=0.4361 hard@0.50=0.4363 | P=0.303 R=0.778 | HD=76.12 HD95=59.90 ASSD=9.68
# [50/138] soft=0.6812 hard@0.50=0.6817 | P=0.610 R=0.773 | HD=42.87 HD95=28.34 ASSD=5.19
# [60/138] soft=0.8040 hard@0.50=0.8047 | P=0.822 R=0.788 | HD=48.70 HD95=4.24 ASSD=1.41
# [70/138] soft=0.7514 hard@0.50=0.7528 | P=0.724 R=0.784 | HD=17.32 HD95=4.36 ASSD=1.35
# [80/138] soft=0.4476 hard@0.50=0.4503 | P=0.672 R=0.339 | HD=38.79 HD95=32.60 ASSD=7.71
# [90/138] soft=0.7135 hard@0.50=0.7145 | P=0.715 R=0.714 | HD=80.09 HD95=33.56 ASSD=6.28
# [100/138] soft=0.0000 hard@0.50=0.0000 | P=0.000 R=0.000 | HD=nan HD95=nan ASSD=nan
# [110/138] soft=0.4544 hard@0.50=0.4567 | P=0.438 R=0.477 | HD=51.40 HD95=23.13 ASSD=5.12
# [120/138] soft=0.5242 hard@0.50=0.5256 | P=0.690 R=0.425 | HD=37.71 HD95=22.32 ASSD=4.49
# [130/138] soft=0.1703 hard@0.50=0.1751 | P=0.968 R=0.096 | HD=10.86 HD95=8.72 ASSD=3.23
# [138/138] soft=0.0000 hard@0.50=0.0000 | P=0.000 R=0.000 | HD=56.36 HD95=54.63 ASSD=23.42
#
# === SUMMARY ===
# Macro soft Dice : 0.5088
# Macro hard Dice : 0.5096
# Micro soft Dice : 0.6866
# Micro hard Dice : 0.6871
# Per-case CSV    : /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_metrics_20251111_161029.csv
# Summary  JSON   : /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_metrics_summary_20251111_161029.json
# Composite figure: /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_composite_20251111_161029.png
# Merged CSV with manifest -> /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_metrics_with_manifest_20251111_161029.csv
# Wrote summary CSV -> /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_summary_stats.csv
# Datasets ready for plotting: ['lores']
# Rows: 138 | Saved per-case CSV: /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_metrics_20251111_161029.csv
# Saved one-row summary CSV: /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/test_lores_summary_stats.csv

# %%
# === Pretty grouped violins (final tweaks) ===
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from pathlib import Path
from typing import Dict, Any, List

PALETTE       = ["#4C78A8"]      # add more colors if plotting multiple datasets
POINT_ALPHA   = 0.55
POINT_SIZE    = 10
VIOLIN_ALPHA  = 0.18             # extra transparent so dots show clearly
EDGE_ALPHA    = 0.35
ROBUST_PERC   = (5, 95)
JITTER_WIDTH  = 0.08
SEED          = 7
_rng = np.random.default_rng(SEED)

def _dropna(a): 
    a = np.asarray(a, float); 
    return a[~np.isnan(a)]

def _robust_limits_linear(arr, p=(5,95), min_span=1e-6):
    arr = _dropna(arr)
    if arr.size == 0: return (0.0, 1.0)
    lo, hi = np.percentile(arr, p[0]), np.percentile(arr, p[1])
    if hi - lo < min_span: hi = lo + min_span
    return float(lo), float(hi)

def _beeswarm_x(center: float, n: int, spread: float) -> np.ndarray:
    if n == 0: return np.array([])
    return center + _rng.normal(0.0, spread, size=n)

def _get_val(row: Dict[str, Any], key: str):
    if key == "soft": return row.get("soft", row.get("soft_dice"))
    if key == "hard":
        for k in row.keys():
            if k.startswith("hard_dice"): return row[k]
        return row.get("hard")
    if key == "prec": return row.get("prec", row.get("precision"))
    if key == "rec":  return row.get("rec",  row.get("recall"))
    return row.get(key)  # hd, hd95, assd

def pretty_violins_from_datasets(
    datasets: Dict[str, Dict[str, Any]],
    title: str = "Higher Resolution Images Test Set",
    legend_label: str = "Individual Image Segmentation",
    distance_units: str = "mm",
    save_path = None,
    show_legend = False
):
    if not datasets:
        print("No datasets to plot."); 
        return None
    

    tags = sorted(datasets.keys())

    def metric_arrays(std_key: str) -> List[np.ndarray]:
        return [ _dropna([_get_val(r, std_key) for r in datasets[tag]["rows"]]) for tag in tags ]

    # arrays
    soft, hard, prec, rec  = (metric_arrays(k) for k in ["soft","hard","prec","rec"])
    hd, hd95, assd         = (metric_arrays(k) for k in ["hd","hd95","assd"])

    plt.style.use("default")
    fig = plt.figure(figsize=(12, 8))
    gs  = GridSpec(2, 1, height_ratios=[3, 2], hspace=0.40)
    ax_top = fig.add_subplot(gs[0])
    ax_bot = fig.add_subplot(gs[1])

    def draw_grouped(ax, data_seq: List[List[np.ndarray]], base_labels: List[str],
                    ylabel=None, panel_title=None, is_distance=False):
        groups = len(data_seq)
        nd     = len(tags)
        base_x = np.arange(1, groups+1, dtype=float)
        width, step = 0.9, 0.9/(nd+1)

        # remove any leftover legend from previous runs
        leg = ax.get_legend()
        if leg is not None:
            leg.remove()

        all_vals = []
        for di, tag in enumerate(tags):
            color  = PALETTE[di % len(PALETTE)]
            offset = (di - (nd-1)/2) * step
            for gi in range(groups):
                vals = data_seq[gi][di]
                all_vals.append(vals)
                pos = base_x[gi] + offset
                parts = ax.violinplot([vals if vals.size else np.array([np.nan])],
                                    positions=[pos], widths=step*0.95,
                                    showmeans=True, showmedians=True)
                for b in parts.get('bodies', []):
                    b.set_facecolor(color)
                    b.set_edgecolor((0,0,0,EDGE_ALPHA))
                    b.set_alpha(VIOLIN_ALPHA)
                if 'cmeans' in parts:
                    parts['cmeans'].set_linewidth(1.6); parts['cmeans'].set_color((0,0,0,0.85))
                if 'cmedians' in parts:
                    parts['cmedians'].set_linewidth(1.6); parts['cmedians'].set_color((0,0,0,0.85))
                if vals.size:
                    xs = _beeswarm_x(pos, len(vals), JITTER_WIDTH)
                    ax.scatter(xs, vals, s=POINT_SIZE, alpha=POINT_ALPHA, color=color, edgecolor='none')

        ax.set_xticks(base_x)
        ax.set_xticklabels(base_labels)
        if ylabel: ax.set_ylabel(ylabel)
        if panel_title: ax.set_title(panel_title, pad=18)
        flat = np.concatenate([v for v in all_vals if v.size]) if any(v.size for v in all_vals) else np.array([])
        if flat.size:
            lo, hi = _robust_limits_linear(flat, p=ROBUST_PERC)
            if not is_distance:
                lo = max(0.0, lo); hi = min(1.0, max(0.9, hi))
            ax.set_ylim(lo, hi)
        ax.grid(True, axis='y', alpha=0.25)

        # only add legend if requested
        if show_legend:
            ax.plot([], [], marker='o', ls='', color=PALETTE[0], label=legend_label)
            ax.legend(loc="upper left", bbox_to_anchor=(1.23, 1.03), frameon=False)


    # Top (Dice/PR)
    draw_grouped(
        ax_top,
        data_seq=[soft, hard, prec, rec],
        base_labels=["Soft Dice", "Hard Dice", "Precision", "Recall"],
        ylabel="Value",
        panel_title="Per-case distributions (Dice / Precision / Recall)",
        is_distance=False
    )

    # Bottom (Distances) — linear + units
    draw_grouped(
        ax_bot,
        data_seq=[hd, hd95, assd],
        base_labels=["HD", "HD95", "ASSD"],
        ylabel=f"Distance ({distance_units})",
        panel_title="Surface distance metrics (per-case)",
        is_distance=True
    )

    # Figure title (exact text you asked for)
    fig.suptitle(title, y=0.99, fontsize=16)
    plt.tight_layout()

    # Save
    if save_path is None:
        any_row = next(iter(datasets[tags[0]]["rows"]), None)
        default_dir = Path(any_row["img_path"]).parent if any_row and any_row.get("img_path") else Path(".")
        save_path = default_dir / "pretty_violins_linear_final.png"
    fig.savefig(save_path, dpi=180, bbox_inches="tight")
    print("Saved figure ->", save_path)

    plt.show()
    return fig

# %%
# Cell 4: call the plotter for the lores run
from pathlib import Path

pretty_violins_from_datasets(
    datasets,                              # this was built in your new Cell 3
    title="Downsampled to Thick Slices",
    distance_units="mm",
    show_legend=False,
    save_path=Path("/home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/lores_pretty_violins.png")
)
# Out:
# Saved figure -> /home/rbielski/stroke_cleaned/ARC_ATLAS_Combined/ARC_ATLAS_Train_v3/runs/20251110_101813/test_eval/lores_pretty_violins.png
